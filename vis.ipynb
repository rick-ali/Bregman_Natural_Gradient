# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Assuming your CSV file is named 'your_file.csv'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(x = [1,2,3], y=[4,5,6], linestyle='-')
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df1= pd.read_csv('metrics1.csv')
df = pd.read_csv('metrics.csv')
sns.set_theme(style="whitegrid")
# Create the line plot with a grid
plt.figure(figsize=(10, 6))
sns.lineplot(data=df,  x='epoch', y='entropy', linestyle='-')
sns.lineplot( x=df['epoch'], y=df1['entropy'][::160], linestyle='-')
# Out:
# <Axes: xlabel='epoch', ylabel='entropy'>

# %%
(df1['loss'][40000::1000])
# Out:
# 40000    0.006256
# 41000    0.004802
# 42000    0.005306
# 43000    0.005271
# 44000    0.005032
# 45000    0.005029
# 46000    0.004314
# 47000    0.003772
# 48000    0.002363
# 49000    0.004444
# 50000    0.002088
# 51000    0.002374
# 52000    0.001763
# 53000    0.001416
# 54000    0.001362
# 55000    0.001242
# 56000    0.002628
# 57000    0.001912
# 58000    0.000750
# 59000    0.002472
# 60000    0.000592
# 61000    0.000491
# 62000    0.002248
# 63000    0.000575
# 64000    0.000628
# 65000    0.000409
# 66000    0.000559
# 67000    0.000289
# 68000    0.001634
# 69000    0.000215
# 70000    0.000560
# 71000    0.000631
# 72000    0.000647
# 73000    0.000358
# 74000    0.000244
# 75000    0.000189
# 76000    0.000296
# 77000    0.000123
# 78000    0.000119
# 79000    0.000220
# Name: loss, dtype: float64

# %%
df1['loss'][:47000:1000]
# Out:
# 0        0.630721
# 1000     0.226481
# 2000     0.194945
# 3000     0.174969
# 4000     0.161047
# 5000     0.151604
# 6000     0.145222
# 7000     0.138925
# 8000     0.133329
# 9000     0.128008
# 10000    0.121795
# 11000    0.112024
# 12000    0.098046
# 13000    0.086257
# 14000    0.076137
# 15000    0.065041
# 16000    0.055252
# 17000    0.047396
# 18000    0.040410
# 19000    0.033907
# 20000    0.028473
# 21000    0.024502
# 22000    0.021813
# 23000    0.019796
# 24000    0.018081
# 25000    0.016584
# 26000    0.015121
# 27000    0.013597
# 28000    0.013386
# 29000    0.011625
# 30000    0.013478
# 31000    0.014264
# 32000    0.013270
# 33000    0.010277
# 34000    0.009076
# 35000    0.009233
# 36000    0.005740
# 37000    0.005396
# 38000    0.010641
# 39000    0.005708
# 40000    0.006256
# 41000    0.004802
# 42000    0.005306
# 43000    0.005271
# 44000    0.005032
# 45000    0.005029
# 46000    0.004314
# Name: loss, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df1= pd.read_csv('metrics1.csv')
df = pd.read_csv('metrics.csv')
sns.set_theme(style="whitegrid")
# Create the line plot with a grid
plt.figure(figsize=(10, 6))
sns.lineplot(data=df,  x='epoch', y='loss', linestyle='-')
sns.lineplot( x=df['epoch'], y=list(df1['loss'][:47000:94]), linestyle='-')
# Out:
# <Axes: xlabel='epoch', ylabel='loss'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df1= pd.read_csv('metrics1.csv')
df = pd.read_csv('metrics.csv')
sns.set_theme(style="whitegrid")
# Create the line plot with a grid
plt.figure(figsize=(10, 6))
sns.lineplot(data=df,  x='epoch', y='entropy', linestyle='-')
sns.lineplot( x=df['epoch'], y=list(df1['entropy'][:47000:94]), linestyle='-')
# Out:
# <Axes: xlabel='epoch', ylabel='entropy'>
